# %% [markdown]
# <a href="https://colab.research.google.com/github/pranitakhade/COB-Data-Science/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
api_url = 'https://dummyjson.com/products'
response = requests.get(api_url)

if response.status_code == 200:
    data = response.json()
else:
    print(f"Failed to fetch data from the API. Status code: {response.status_code}")
    data = []

# %%
#Convert data to a Pandas DataFrame
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                             products  total  skip  limit
# 0  {'id': 1, 'title': 'iPhone 9', 'description': ...    100     0     30
# 1  {'id': 2, 'title': 'iPhone X', 'description': ...    100     0     30
# 2  {'id': 3, 'title': 'Samsung Universe 9', 'desc...    100     0     30
# 3  {'id': 4, 'title': 'OPPOF19', 'description': '...    100     0     30
# 4  {'id': 5, 'title': 'Huawei P30', 'description'...    100     0     30

# %%
#Saving Dataframe to a CSV File

dummyjson_products = 'dataset.csv'
df.to_csv(dummyjson_products, index=False)
